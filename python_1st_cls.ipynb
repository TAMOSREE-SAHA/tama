# %% [markdown]
# <a href="https://colab.research.google.com/github/TAMOSREE-SAHA/tama/blob/main/python_1st_cls.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("welcome")
print("\t summation: ", 10+11,"\n subtraction:", 200-100)

# this is for data science
# Out:
# welcome
# 	 summation:  21
#  subtraction: 100

# %%
#input
## int(input)
n=int(input("enter the number: "))
m=int(input("Enter "))

print("Result ",n+m)
# Cancatenation abc + xyz =abcxyz
# Out:
# enter the number: 3
# Enter 3
# Result  6

# %%
x=123.123
x1=123
x3="asf"

print(type(x))
# Out:
# <class 'float'>

# %%
num1 =100
num2=200

#==

res=num1==num2
print(res)



num1 =100
num2=200

print(num1!=num2)
# Out:
# False
# True

# %%
#condition


num1 =9
num2=200

if num1 % 2 == 0:
  print("even") #indentation-->this space which mention the if body

else:
  print("odd")
# Out:
# odd

# %%
#condition


num1 =9
num2=200
num3=33

if num1 > num2 and num1> num3:
  print(num1, " is Greater") #indentation-->this space which mention the if body
elif num2 > num1 and num2> num3:
  print(num2, " is Greater")
else:
  print(num3, " is Greater")
# Out:
# 200  is Greater

# %%
# print 1 to 100

for x in range(1, 3): ## 3 parameter possible
  print(x)

for x in range( 3): ##
  print(x)
  print("ok")

for x in range(1, 10, 3): ##
  print(x)

for x in range(0, 10, 2): ##
  print(x)
# Out:
# 1
# 2
# 0
# ok
# 1
# ok
# 2
# ok
# 1
# 4
# 7
# 0
# 2
# 4
# 6
# 8

# %%
#while
#starting, End/condition, Inc/Dec

x=0

while x<=2:
  print(x)
  x=x+1

x=1
while x<=12:
  print(2**x)
  x=x+1
# Out:
# 0
# 1
# 2
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512
# 1024
# 2048
# 4096

# %%
n=90
x=300
r=n+x

y=x % n
# = is assignment operator

print("sum = ",r)

print("reminder ",y)

#floating: 22.002
#integer:300

f=x//n

print("division with int: ", f)
# Out:
# sum =  390
# reminder  30
# division with int:  3

# %%
for x in range(1, 11): ## 3 parameter possible
  if x==6:
    break
  print(x)
print("ok")
# Out:
# 1
# 2
# 3
# 4
# 5
# ok
